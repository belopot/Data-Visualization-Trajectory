# %%
import _pickle as pickle

from base import *
from distance import *
from greedy import *
from base import *
import datetime

import pandas as pd

def readTrajsFromTxtFile(fName):
    df = pd.read_csv(fName,
                     sep=',',
                     header=None,
                     names=['trajID', 't', 'lat', 'lon'],
                     comment='#')
    df['t'] = pd.to_datetime(df.t)
    df = df.sort_values(by='t')
    df = df.groupby(by='trajID')
    return df

if __name__ == "__main__":

    print("Loading trajectories ...")
    trajs = readTrajsFromTxtFile("data/new.txt")
    # print(("trajectories are",trajs))
    rmin, rmax = 0.5, 2

    print("Computing Frechet distances ...")
    distPairs1 = process(trajs, rmin, rmax)
    # print(("Output of Frechet distance", distPairs1))
    distPairs2 = {}
    for k, v in distPairs1.items():
        pth, trID, dist, straj = k[0], k[1].trajID, v, k[1]
        if (pth, trID) in distPairs2:
            distPairs2[(pth, trID)].append((straj, dist))
        else:
            distPairs2[(pth, trID)] = [(straj, dist)]
    print("Computing prerequisite data structures for greedy algorithm ...")
    (strajCov, ptStraj, strajPth, trajCov) = preprocess(trajs, distPairs2)
    #print("Pre-requiste data structure are:")
    # print(("strajCov",strajCov))
    # print(("ptStraj",ptStraj))
    # print(("strajPth",strajPth))
    # print(("trajCov",trajCov))

    c1, c2, c3 = 1, 1.5, 0.005

    print("Running greedy algorithm ...")
    retVal = Greedy(trajs, distPairs2, strajCov, ptStraj,
                    strajPth, trajCov, c1, c2, c3)
    #print(("Bundle assigned and unassigned points are",retVal))
# Out:
# Loading trajectories ...
# Computing Frechet distances ...
# Computing prerequisite data structures for greedy algorithm ...
# Running greedy algorithm ...
# {1010: (<base.subTraj object at 0x00000228D26E3550>, 0)}
# {1010: (<base.subTraj object at 0x00000228D26E35C0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B5F8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B438>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B6A0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B748>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B4E0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B5C0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B780>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B7B8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B7F0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B710>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B4A8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B6D8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B668>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B630>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B470>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B550>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B828>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B860>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B898>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B8D0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B908>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B940>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B978>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B9B0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B9E8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BA20>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BA58>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BA90>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BAC8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BB00>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BB38>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BB70>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BBA8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BBE0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BC18>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BC50>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BC88>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BCC0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BCF8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BD30>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BD68>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BDA0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BDD8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BE10>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BE48>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BE80>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BEB8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BF98>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BEF0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BF28>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B518>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BFD0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538BF60>, 0)}
# {1010: (<base.subTraj object at 0x00000228D538B588>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A61D0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6198>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6240>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A60F0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6160>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6278>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6128>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6080>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A60B8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A62B0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A62E8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6320>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A64A8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A64E0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A63C8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6390>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6438>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6550>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6208>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6470>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6518>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6358>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6588>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A65C0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A65F8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6630>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6668>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A66A0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A66D8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6710>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6748>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6780>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A67B8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A67F0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6828>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6860>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6898>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A68D0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6908>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6940>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6978>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A69B0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A69E8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6A20>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6BA8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6BE0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6AC8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6A90>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6B38>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6C50>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6400>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6B70>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6C18>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6A58>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6C88>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6CC0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6CF8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6D30>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6D68>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6DA0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6F28>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6F60>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6E48>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6E10>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6EB8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6F98>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6FD0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6B00>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6E80>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6DD8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6EF0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A6048>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8080>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8198>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A80B8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A82E8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8240>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A83C8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A81D0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A80F0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8400>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8438>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8160>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8048>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8390>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8358>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A82B0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8320>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8278>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8470>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A84A8>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A84E0>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A8518>, 0)}
# {1010: (<base.subTraj object at 0x00000228D35A
, 0)}
# {10208: (<base.subTraj object at 0x00000228D647D0B8>, 0)}
# {10208: (<base.subTraj object at 0x00000228D647D198>, 0)}
# ('number of Unprocessed Points', [274846])
# number of poits is 274846
# Error!! Coverage should have been 0, instead of 194
# number of poits is 270145
# Error!! Coverage should have been 0, instead of 260
# number of poits is 265586
# Error!! Coverage should have been 0, instead of 783
# number of poits is 261941
# Error!! Coverage should have been 0, instead of 193
# number of poits is 257727
# Error!! Coverage should have been 0, instead of 1383
# number of poits is 254989
# Error!! Coverage should have been 0, instead of 217
# number of poits is 251459
# Error!! Coverage should have been 0, instead of 141
# number of poits is 248082
# Error!! Coverage should have been 0, instead of 137
# number of poits is 244803
# Error!! Coverage should have been 0, instead of 642
# number of poits is 242131
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1b635a6bf81d> in <module>()
#      50     print("Running greedy algorithm ...")
#      51     retVal = Greedy(trajs, distPairs2, strajCov, ptStraj,
# ---> 52                     strajPth, trajCov, c1, c2, c3)
#      53     #print(("Bundle assigned and unassigned points are",retVal))
#
# ~\Downloads\subtrajectory (4)\greedy.py in Greedy(trajs, distPairs, strajCov, ptStraj, strajPth, trajCov, c1, c2, c3)
#     333             affectedPths = affectedPths.union(
#     334                 processTraj(trID, ptStraj, strajCov, strajPth, trajs, trajCov, distPairs, numUnprocessedPts, queue2,
# --> 335                             unassignedPts))
#     336
#     337         # Update coverage-cost ratio of affected pathlets.
#
# ~\Downloads\subtrajectory (4)\greedy.py in processTraj(trID, ptStraj, strajCov, strajPth, trajs, trajCov, distPairs, numUnprocessedPts, queue, unassignedPts)
#     128             Set having pathlet-trajID pairs to which point can be processed.
#     129     """
# --> 130     points = trajs[trID].pts
#     131     retVal = set()
#     132     for i in range(len(points)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     265         else:
#     266             if key not in self.obj:
# --> 267                 raise KeyError("Column not found: {key}".format(key=key))
#     268             return self._gotitem(key, ndim=1)
#     269
#
# KeyError: 'Column not found: 10011'

# %%
# Out:
#                 trajID          t        lat       lon
# 1  2008-02-02 15:36:08 1970-01-01 -122.39534  37.77678
# 2  2008-02-02 20:52:33 1970-01-01 -122.40584  37.78564
# 2  2008-02-02 20:51:33 1970-01-01 -122.40480  37.78666
# 2  2008-02-02 20:50:33 1970-01-01 -122.40301  37.78708
# 2  2008-02-02 20:40:33 1970-01-01 -122.39978  37.78438
# 2  2008-02-02 20:30:34 1970-01-01 -122.39566  37.78113
# 2  2008-02-02 17:10:24 1970-01-01 -122.39314  37.77846
# 2  2008-02-02 17:00:24 1970-01-01 -122.39460  37.77679
# 2  2008-02-02 16:36:08 1970-01-01 -122.39472  37.77672
# 1  2008-02-02 16:31:08 1970-01-01 -122.41435  37.80129
# 1  2008-02-02 16:30:08 1970-01-01 -122.41392  37.79890
# 1  2008-02-02 16:29:08 1970-01-01 -122.41316  37.79510
# 1  2008-02-02 16:28:08 1970-01-01 -122.41252  37.79232
# 1  2008-02-02 16:27:08 1970-01-01 -122.41207  37.78954
# 1  2008-02-02 16:26:08 1970-01-01 -122.41103  37.78463
# 1  2008-02-02 16:16:08 1970-01-01 -122.40837  37.78066
# 1  2008-02-02 16:06:08 1970-01-01 -122.40801  37.78043
# 1  2008-02-02 15:56:08 1970-01-01 -122.40553  37.77848
# 1  2008-02-02 15:46:08 1970-01-01 -122.40235  37.77594
# 1  2008-02-02 15:46:08 1970-01-01 -122.39920  37.77631
# 2  2008-02-02 20:53:33 1970-01-01 -122.40826  37.78385
# 2  2008-02-02 20:54:33 1970-01-01 -122.41061  37.78321
